# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('pokemon_data.csv',index_col=0)

df.plot()
plt.show()

# %%
fig, ax = plt.subplots()

bar_width = 0.5
print(bar_width)
y=["dog","cat","mouse","duck"]
x=[1,4,9,16]

ax.barh(y, x)
plt.show()
# Out:
# 0.5
